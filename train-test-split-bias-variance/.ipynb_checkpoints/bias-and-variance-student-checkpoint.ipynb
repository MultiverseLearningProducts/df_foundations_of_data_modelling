# %%
from IPython.display import HTML
from IPython.display import Javascript

from IPython.display import display

# Taken from https://stackoverflow.com/questions/31517194/how-to-hide-one-specific-cell-input-or-output-in-ipython-notebook
tag = HTML("""<script>
code_show=true; 
function code_toggle() {
    if (code_show){
        $('div.cell.code_cell.rendered.selected div.input').hide();
    } else {
        $('div.cell.code_cell.rendered.selected div.input').show();
    }
    code_show = !code_show
} 
$( document ).ready(code_toggle);

var flagHighlight=0;
var flagHighlightCode = 0;
var flagMagnifyCell = 0;
var flagMagnifyCode =0;
var flagMagnifyOutputs=0;
var flagEnlarge = 0;
var flagHighlightOutput = 0;

function enlarge_markdown(){
    
if(flagEnlarge==0){
flagEnlarges = 1;
document.getElementById('button7').classList.toggle('active_button');
var els = document.getElementsByClassName('text_cell');
var i;
for(i=0;i<els.length;i++){
els[i].classList.toggle('enlarged');}}
else{
flagEnlarge = 0;
document.getElementById('button7').classList.toggle('active_button');
var els = document.getElementsByClassName('text_cell');
var i;
for(i=0;i<els.length;i++){
els[i].classList.remove('enlarged');
}};};


function magnify_outputs(){
    
if(flagMagnifyOutputs==0){
flagMagnifyOutputs = 1;
document.getElementById('button5').classList.toggle('active_button');
var els = document.getElementsByClassName('output_wrapper');
var i;
for(i=0;i<els.length;i++){
els[i].classList.toggle('magnified_output');}}
else{
flagMagnifyOutputs = 0;
document.getElementById('button5').classList.toggle('active_button');
var els = document.getElementsByClassName('output_wrapper');
var i;
for(i=0;i<els.length;i++){
els[i].classList.remove('magnified_output');
}};};

function magnify_output_lines(){
    
if(flagHighlightOutput==0){
flagHighlightOutput = 1;
document.getElementById('button6').classList.toggle('active_button');
var els = document.getElementsByClassName('output_wrapper');
var i;
for(i=0;i<els.length;i++){
els[i].classList.toggle('magnified_output_lines');}}
else{flagHighlightOutput = 0;
document.getElementById('button6').classList.toggle('active_button');
var els = document.getElementsByClassName('output_wrapper');
var i;
for(i=0;i<els.length;i++){
els[i].classList.remove('magnified_output_lines');
}};};


function highlight_cell(){
    
if(flagHighlight==0){
flagHighlight = 1;
document.getElementById('button4').classList.toggle('active_button');
var els = document.getElementsByClassName('CodeMirror-lines');
var i;
for(i=0;i<els.length;i++){
els[i].classList.toggle('highlighted');}}
else{flagHighlight = 0;
document.getElementById('button4').classList.toggle('active_button');
var els = document.getElementsByClassName('CodeMirror-lines');
var i;
for(i=0;i<els.length;i++){
els[i].classList.remove('highlighted');
}};};


function highlight_code(){   
if(flagHighlightCode==0){

flagHighlightCode = 1;
document.getElementById('button3').classList.toggle('active_button');
var els = document.getElementsByClassName('CodeMirror-lines');
var i;
for(i=0;i<els.length;i++){
els[i].classList.toggle('highlighted_code');}}   
else{flagHighlightCode = 0;
document.getElementById('button3').classList.toggle('active_button');
var els = document.getElementsByClassName('CodeMirror-lines');
var i;
for(i=0;i<els.length;i++){
els[i].classList.remove('highlighted_code');
}};};

function magnify_cell(){   
if(flagMagnifyCell==0){
flagMagnifyCell = 1;
document.getElementById('button2').classList.toggle('active_button');
var els = document.getElementsByClassName('CodeMirror-lines');
var i;
for(i=0;i<els.length;i++){
els[i].classList.toggle('magnified_cell');}}   
else{flagMagnifyCell = 0;
document.getElementById('button2').classList.toggle('active_button');
var els = document.getElementsByClassName('CodeMirror-lines');
var i;
for(i=0;i<els.length;i++){
els[i].classList.remove('magnified_cell');
}};};

function magnify_code(){   
if(flagMagnifyCode==0){
flagMagnifyCode = 1;
document.getElementById('button1').classList.toggle('active_button');
var els = document.getElementsByClassName('CodeMirror-lines');
var i;
for(i=0;i<els.length;i++){
els[i].classList.toggle('magnified_code');}}   
else{flagMagnifyCode = 0;
document.getElementById('button1').classList.toggle('active_button');
var els = document.getElementsByClassName('CodeMirror-lines');
var i;
for(i=0;i<els.length;i++){
els[i].classList.remove('magnified_code');
}};};


document.getElementsByTagName("BODY")[0].insertAdjacentHTML("afterend", "<div id='help_box'></div>");
document.getElementsByTagName("BODY")[0].insertAdjacentHTML("afterend","<img src= 'https://img.flaticon.com/icons/png/512/25/25186.png?size=1200x630f&pad=10,10,10,10&ext=png&bg=FFFFFFFF' id='mvlogo'>")
document.getElementsByTagName("BODY")[0].insertAdjacentHTML("afterend", "<div class='hidden' id='tooltip2'><p>click the eye to hide/show tools</p></div>");
var help_box = document.getElementById('help_box');

help_box.classList.add('floater');

help_box.innerHTML = "<h2 id='heading'><b>Visual tools</b></h2><button id='button1' class='clean_buttons'>Magnify lines </button><button id='button2'class = 'clean_buttons' >Enlarge cells</button><button id='button3' class = 'clean_buttons' >highlight lines</button><button id='button4' class = 'clean_buttons' >highlight cell</button>";
help_box.innerHTML +="<button id='button5' class='clean_buttons'>Enlarge</button><button id='button6' class='clean_buttons'>Highlight</button>"
help_box.innerHTML += "<button id='button7' class='clean_buttons'>enlarge</button"
help_box.innerHTML+= "<p class='sections' id='code_heading'><b>Code</b></p>"
help_box.innerHTML+= "<p class='sections' id='output_heading'><b>Outputs</b></p>"
help_box.innerHTML+= "<p class='sections' id='markdown_heading'><b>Markdowns</b></p>"
help_box.innerHTML +="<p id='credit'>logo credit to https://www.flaticon.com/free-icon/eye-open_25186 <br>  used under open license: Attribution 3.0 Unported (CC BY 3.0)<br> Coded by N.Griffiths employed by Muliverse </p>"
document.body.appendChild(help_box);

document.getElementById('button7').addEventListener('click',function(){
   enlarge_markdown();});
    
document.getElementById('button6').addEventListener('click',function(){
    magnify_output_lines();});

document.getElementById('button5').addEventListener('click',function(){
    magnify_outputs();});
    
document.getElementById('button4').addEventListener('click',function(){
    highlight_cell();});

document.getElementById('button3').addEventListener('click',function(){
    highlight_code();});

document.getElementById('button2').addEventListener('click',function(){
    magnify_cell();});

document.getElementById('button1').addEventListener('click',function(){
    magnify_code();});
 
document.getElementById('mvlogo').addEventListener('click',function(){  
document.getElementById('help_box').classList.toggle('hidden');}); 
 
 
document.getElementById('mvlogo').addEventListener('mouseover',function(){  
document.getElementById('tooltip2').classList.toggle('hidden');});

document.getElementById('mvlogo').addEventListener('mouseout',function(){  
document.getElementById('tooltip2').classList.toggle('hidden');});


</script>
<a id='boilerplate' href="javascript:code_toggle()">change js running visual-aids</a>.


<style>

.hidden{
display:none;
}

#credit{
position: fixed;
top:65.5vh;
left:81vw;
font-size:0.9vmin;
}
#boilerplate{
color:white;
}

#boilerplate:hover{
color:blue;
}

#tooltip2{
position:fixed;
z-index:1001;
left:80vw;
top:18vh;
font-size:1.5vh;
background-color:white;
}

.floater{
background-color:#FFFFFF;
color:#003b49;
border-style:solid;
border-color:#003b49;
borderwidth:0.1vh;
z-index:1000;
position:fixed;
left: 80vw;
Top: 20vh;
height: 53vh;
width: 18vw;

}

#heading{
position:fixed;
top:21vh;
left:80vw;
margin: 1vh 1vh 1vh  1vh;
font-size:3vmin;}

.clean_buttons{
padding: 0px 0px 0px 0px;
background-color:#d0d3d4;
color:#003b49;
cursor: pointer;
width:8vw;
height:6vh;
font-size:2vmin;
border-width:0.1vh;
}
#button1{
position:fixed;
top:31vh;
left:80.5vw;
}
#button2{
position:fixed;
top:31vh;
left:89vw;
}
#button3{
position:fixed;
top:38vh;
left:80.5vw;
}
#button4{
position:fixed;
top:38vh;
left:89vw;
}
#button5{
position:fixed;
top:48.5vh;
left:80.5vw;
}
#button6{
position:fixed;
top:48.5vh;
left:89vw;
}
#button7{
position:fixed;
top:58vh;
left: 84vw;
}
.active_button{
background:#003b49;
color:#d0d3d4;
}

.sections{
font-size: 2vmin;
left:82vw;
}
#code_heading{
position:fixed;
top:28vh;
}
#output_heading{
position:fixed;
top:45vh;
}
#markdown_heading{
position:fixed;
top:55vh;
}

#mvlogo{
width:18vw;
height:8vh;
object-fit: cover;
position:fixed;
z-index:1000;
left: 80vw;
top: 10vh;
border: 0.5vh solid #003b49;
cursor: pointer;
}

.highlighted :hover{
background-color:#fcfaeb;
}

.highlighted_code div pre :hover{
background-color:yellow;
}

.magnified_code div pre span:hover{
margin-top:3vh;
margin-bottom:3vh;
height:30px;
width:auto;
font-size:130%;}

.magnified_cell div pre{
padding: 6px 0px 6px 0px;
}

.magnified_cell div{
font-size:120%;
line-height:120%;
}

.magnified_output *{
font-size: 115%;
}

.magnified_output_lines :hover{
background-color:#FFFF99;
color:purple;

}

.enlarged *  {
font-size:120%;
line-height:120%;

}



</style>
""")

display(tag)
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#     if (code_show){
#         $('div.cell.code_cell.rendered.selected div.input').hide();
#     } else {
#         $('div.cell.code_cell.rendered.selected div.input').show();
#     }
#     code_show = !code_show
# }
# $( document ).ready(code_toggle);
#
# var flagHighlight=0;
# var flagHighlightCode = 0;
# var flagMagnifyCell = 0;
# var flagMagnifyCode =0;
# var flagMagnifyOutputs=0;
# var flagEnlarge = 0;
# var flagHighlightOutput = 0;
#
# function enlarge_markdown(){
#
# if(flagEnlarge==0){
# flagEnlarges = 1;
# document.getElementById('button7').classList.toggle('active_button');
# var els = document.getElementsByClassName('text_cell');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.toggle('enlarged');}}
# else{
# flagEnlarge = 0;
# document.getElementById('button7').classList.toggle('active_button');
# var els = document.getElementsByClassName('text_cell');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.remove('enlarged');
# }};};
#
#
# function magnify_outputs(){
#
# if(flagMagnifyOutputs==0){
# flagMagnifyOutputs = 1;
# document.getElementById('button5').classList.toggle('active_button');
# var els = document.getElementsByClassName('output_wrapper');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.toggle('magnified_output');}}
# else{
# flagMagnifyOutputs = 0;
# document.getElementById('button5').classList.toggle('active_button');
# var els = document.getElementsByClassName('output_wrapper');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.remove('magnified_output');
# }};};
#
# function magnify_output_lines(){
#
# if(flagHighlightOutput==0){
# flagHighlightOutput = 1;
# document.getElementById('button6').classList.toggle('active_button');
# var els = document.getElementsByClassName('output_wrapper');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.toggle('magnified_output_lines');}}
# else{flagHighlightOutput = 0;
# document.getElementById('button6').classList.toggle('active_button');
# var els = document.getElementsByClassName('output_wrapper');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.remove('magnified_output_lines');
# }};};
#
#
# function highlight_cell(){
#
# if(flagHighlight==0){
# flagHighlight = 1;
# document.getElementById('button4').classList.toggle('active_button');
# var els = document.getElementsByClassName('CodeMirror-lines');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.toggle('highlighted');}}
# else{flagHighlight = 0;
# document.getElementById('button4').classList.toggle('active_button');
# var els = document.getElementsByClassName('CodeMirror-lines');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.remove('highlighted');
# }};};
#
#
# function highlight_code(){
# if(flagHighlightCode==0){
#
# flagHighlightCode = 1;
# document.getElementById('button3').classList.toggle('active_button');
# var els = document.getElementsByClassName('CodeMirror-lines');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.toggle('highlighted_code');}}
# else{flagHighlightCode = 0;
# document.getElementById('button3').classList.toggle('active_button');
# var els = document.getElementsByClassName('CodeMirror-lines');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.remove('highlighted_code');
# }};};
#
# function magnify_cell(){
# if(flagMagnifyCell==0){
# flagMagnifyCell = 1;
# document.getElementById('button2').classList.toggle('active_button');
# var els = document.getElementsByClassName('CodeMirror-lines');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.toggle('magnified_cell');}}
# else{flagMagnifyCell = 0;
# document.getElementById('button2').classList.toggle('active_button');
# var els = document.getElementsByClassName('CodeMirror-lines');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.remove('magnified_cell');
# }};};
#
# function magnify_code(){
# if(flagMagnifyCode==0){
# flagMagnifyCode = 1;
# document.getElementById('button1').classList.toggle('active_button');
# var els = document.getElementsByClassName('CodeMirror-lines');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.toggle('magnified_code');}}
# else{flagMagnifyCode = 0;
# document.getElementById('button1').classList.toggle('active_button');
# var els = document.getElementsByClassName('CodeMirror-lines');
# var i;
# for(i=0;i<els.length;i++){
# els[i].classList.remove('magnified_code');
# }};};
#
#
# document.getElementsByTagName("BODY")[0].insertAdjacentHTML("afterend", "<div id='help_box'></div>");
# document.getElementsByTagName("BODY")[0].insertAdjacentHTML("afterend","<img src= 'https://img.flaticon.com/icons/png/512/25/25186.png?size=1200x630f&pad=10,10,10,10&ext=png&bg=FFFFFFFF' id='mvlogo'>")
# document.getElementsByTagName("BODY")[0].insertAdjacentHTML("afterend", "<div class='hidden' id='tooltip2'><p>click the eye to hide/show tools</p></div>");
# var help_box = document.getElementById('help_box');
#
# help_box.classList.add('floater');
#
# help_box.innerHTML = "<h2 id='heading'><b>Visual tools</b></h2><button id='button1' class='clean_buttons'>Magnify lines </button><button id='button2'class = 'clean_buttons' >Enlarge cells</button><button id='button3' class = 'clean_buttons' >highlight lines</button><button id='button4' class = 'clean_buttons' >highlight cell</button>";
# help_box.innerHTML +="<button id='button5' class='clean_buttons'>Enlarge</button><button id='button6' class='clean_buttons'>Highlight</button>"
# help_box.innerHTML += "<button id='button7' class='clean_buttons'>enlarge</button"
# help_box.innerHTML+= "<p class='sections' id='code_heading'><b>Code</b></p>"
# help_box.innerHTML+= "<p class='sections' id='output_heading'><b>Outputs</b></p>"
# help_box.innerHTML+= "<p class='sections' id='markdown_heading'><b>Markdowns</b></p>"
# help_box.innerHTML +="<p id='credit'>logo credit to https://www.flaticon.com/free-icon/eye-open_25186 <br>  used under open license: Attribution 3.0 Unported (CC BY 3.0)<br> Coded by N.Griffiths employed by Muliverse </p>"
# document.body.appendChild(help_box);
#
# document.getElementById('button7').addEventListener('click',function(){
#    enlarge_markdown();});
#
# document.getElementById('button6').addEventListener('click',function(){
#     magnify_output_lines();});
#
# document.getElementById('button5').addEventListener('click',function(){
#     magnify_outputs();});
#
# document.getElementById('button4').addEventListener('click',function(){
#     highlight_cell();});
#
# document.getElementById('button3').addEventListener('click',function(){
#     highlight_code();});
#
# document.getElementById('button2').addEventListener('click',function(){
#     magnify_cell();});
#
# document.getElementById('button1').addEventListener('click',function(){
#     magnify_code();});
#
# document.getElementById('mvlogo').addEventListener('click',function(){
# document.getElementById('help_box').classList.toggle('hidden');});
#
#
# document.getElementById('mvlogo').addEventListener('mouseover',function(){
# document.getElementById('tooltip2').classList.toggle('hidden');});
#
# document.getElementById('mvlogo').addEventListener('mouseout',function(){
# document.getElementById('tooltip2').classList.toggle('hidden');});
#
#
# </script>
# <a id='boilerplate' href="javascript:code_toggle()">change js running visual-aids</a>.
#
#
# <style>
#
# .hidden{
# display:none;
# }
#
# #credit{
# position: fixed;
# top:65.5vh;
# left:81vw;
# font-size:0.9vmin;
# }
# #boilerplate{
# color:white;
# }
#
# #boilerplate:hover{
# color:blue;
# }
#
# #tooltip2{
# position:fixed;
# z-index:1001;
# left:80vw;
# top:18vh;
# font-size:1.5vh;
# background-color:white;
# }
#
# .floater{
# background-color:#FFFFFF;
# color:#003b49;
# border-style:solid;
# border-color:#003b49;
# borderwidth:0.1vh;
# z-index:1000;
# position:fixed;
# left: 80vw;
# Top: 20vh;
# height: 53vh;
# width: 18vw;
#
# }
#
# #heading{
# position:fixed;
# top:21vh;
# left:80vw;
# margin: 1vh 1vh 1vh  1vh;
# font-size:3vmin;}
#
# .clean_buttons{
# padding: 0px 0px 0px 0px;
# background-color:#d0d3d4;
# color:#003b49;
# cursor: pointer;
# width:8vw;
# height:6vh;
# font-size:2vmin;
# border-width:0.1vh;
# }
# #button1{
# position:fixed;
# top:31vh;
# left:80.5vw;
# }
# #button2{
# position:fixed;
# top:31vh;
# left:89vw;
# }
# #button3{
# position:fixed;
# top:38vh;
# left:80.5vw;
# }
# #button4{
# position:fixed;
# top:38vh;
# left:89vw;
# }
# #button5{
# position:fixe

# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Train/Test Split and Bias and Variance
#
# _Authors: Joseph Nelson (DC), Kevin Markham (DC)_
#
# ---

# %% [markdown]
# <a id="learning-objectives"></a>
# <a id="learning-objectives"></a>
# <a id="learning-objectives"></a>
# ### Learning Objectives
# - Define error due to bias and error due to variance.
# - Identify the bias-variance trade-off.
# - Describe what overfitting and underfitting means in the context of model building.
# - Explain problems associated with over- and underfitting.
# - Grasp why train/test split is necessary.
# - Explore k-folds, LOOCV, and three split methods.

# %% [markdown]
# <a id="bias-and-variance-trade-off"></a>
# # Section 1: Bias and Variance Trade-Off
# ---
#
# The **bias-variance tradeoff** is widely used in machine learning as a conceptual way of comparing and contrasting different models. We only have a few methods that are able to compare all machine learning models. The others are more mathematical.
#
# **Bias** is error stemming from incorrect model assumptions.
# - Example: Assuming data is linear when it has a more complicated structure.
#
# **Variance** is error stemming from being overly sensitive from changes to the training data.
# - Example: Using the training set exactly (e.g. 1-NN) for a model results in a completely different model -- even if the training set differs only slightly.
#
#
# As model complexity **increases**:
# - Bias **decreases**. (The model can more accurately model complex structure in data.)
# - Variance **increases**. (The model identifies more complex structures, making it more sensitive to small changes in the training data.)

# %% [markdown]
# <a id="bias-variance"></a>
# ### Bias? Variance?

# %% [markdown]
# **Conceptual Definitions**
# - **Bias**: How close are predictions to the actual values?
#   - Roughly, whether or not our model aims on target.
#   - If the model cannot represent the data's structure, our predictions could be consistent, but will not be accurate.
# - **Variance**: How variable are our predictions?
#   - Roughly, whether or not our model is reliable.
#   - We will make slightly different predictions given slightly different training sets.

# %% [markdown]
# ![](./assets/biasVsVarianceImage.png)

# %% [markdown]
# - Visually, we are building a model where the bulls-eye is the goal.
# - Each individual hit is one prediction based on our model.
# - Critically, the success of our model (low variance, low bias) depends on the training data present.

# %% [markdown]
# <a id="exploring-the-bias-variance-tradeoff"></a>
# ### Exploring the Bias-Variance Trade-Off

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Allow plots to appear in the notebook.
# %matplotlib inline

# %% [markdown]
# <a id="brain-and-body-weight-mammal-dataset"></a>
# ### Brain and Body Weight Mammal Data Set

# %% [markdown]
# This is a [data set](http://people.sc.fsu.edu/~jburkardt/datasets/regression/x01.txt) of the average weight of the body (in kg) and the brain (in g) for 62 mammal species. We'll use this dataset to investigate bias vs. variance. Let's read it into Pandas and take a quick look:

# %%
path = 'data/mammals.txt'
cols = ['brain','body']
mammals = pd.read_table(path, sep='\t', names=cols, header=0)
mammals.head()
# Out:
#      brain   body
# 0    3.385   44.5
# 1    0.480   15.5
# 2    1.350    8.1
# 3  465.000  423.0
# 4   36.330  119.5

# %%
mammals.describe()
# Out:
#              brain         body
# count    62.000000    62.000000
# mean    198.789984   283.134194
# std     899.158011   930.278942
# min       0.005000     0.140000
# 25%       0.600000     4.250000
# 50%       3.342500    17.250000
# 75%      48.202500   166.000000
# max    6654.000000  5712.000000

# %% [markdown]
# We're going to focus on a smaller subset in which the body weight is less than 200 kg.

# %%
# Only keep rows in which the body weight is less than 200 kg.
mammals = mammals[mammals.body < 200]
mammals.shape
# Out:
# (51, 2)

# %% [markdown]
# We're now going to pretend that there are only 51 mammal species in existence. In other words, we are pretending that this is the entire data set of brain and body weights for **every known mammal species**.
#
# Let's create a scatterplot (using [Seaborn](http://stanford.edu/~mwaskom/software/seaborn/)) to visualize the relationship between brain and body weight:

# %%
sns.lmplot(x='body', y='brain', data=mammals, ci=None, fit_reg=False);
plt.xlim(-10, 200);
plt.ylim(-10, 250);

# %% [markdown]
# There appears to be a relationship between brain and body weight for mammals.

# %% [markdown]
# <a id="making-a-prediction"></a>
# ### Making a Prediction

# %% [markdown]
# Now let's pretend that a **new mammal species** is discovered. We measure the body weight of every member of this species we can find and calculate an **average body weight of 100 kgs**. We want to **predict the average brain weight** of this species (rather than measuring it directly). How might we do this?

# %%
sns.lmplot(x='body', y='brain', data=mammals, ci=None);
plt.xlim(-10, 200);
plt.ylim(-10, 250);

# %% [markdown]
# We drew a straight line that appears to best capture the relationship between brain and body weight. So, we might predict that our new species has a brain weight of about 45 g, as that's the approximate y value when x=100.
#
# This is known as a "linear model" or a "linear regression model."

# %% [markdown]
# <a id="making-a-prediction-from-a-sample"></a>
# ## Making a Prediction From a Sample

# %% [markdown]
# Earlier, we assumed that this dataset contained every known mammal species. That's very convenient, but **in the real world, all you ever have is a sample of data**. This may sound like a contentious statement, but the point of machine learning is to generalize from a sample to the population. If you already have data for the entire population, then you have no need for machine learning -- you can apply statistics directly and get optimal answers!
#
# Here, a more realistic situation would be to only have brain and body weights for (let's say) half of the 51 known mammals.
#
# When that new mammal species (with a body weight of 100 kg) is discovered, we still want to make an accurate prediction for its brain weight, but this task might be more difficult, as we don't have all of the data we would ideally like to have.
#
# Let's simulate this situation by assigning each of the 51 observations to **either universe 1 or universe 2**:

# %%
# Set a random seed for reproducibility.
np.random.seed(12342)

# Randomly assign every observation to either universe 1 or universe 2.
mammals['zoologist'] = np.random.randint(1, 3, len(mammals))
mammals.head()
# Out:
#     brain   body  zoologist
# 0   3.385   44.5          1
# 1   0.480   15.5          2
# 2   1.350    8.1          2
# 4  36.330  119.5          2
# 5  27.660  115.0          2

# %% [markdown]
# **Important:** We only live in one of the two universes. Both universes have 51 known mammal species, but each universe knows the brain and body weight for different species.
#
# We can now tell Seaborn to create two plots in which the left plot only uses the data from **universe 1** and the right plot only uses the data from **universe 2**:

# %%
# col='universe' subsets the data by universe and creates two separate plots.
sns.lmplot(x='body', y='brain', data=mammals, ci=None, col='zoologist');
plt.xlim(-10, 200);
plt.ylim(-10, 250);

# %% [markdown]
# The line looks pretty similar between the two plots, despite the fact that they used separate samples of data. In both cases, we would predict a brain weight of about 45 g.
#
# It's easier to see the degree of similarity by placing them on the same plot:

# %%
# hue='universe' subsets the data by universe and creates a single plot.
sns.lmplot(x='body', y='brain', data=mammals, ci=None, hue='zoologist');
plt.xlim(-10, 200);
plt.ylim(-10, 250);

# %% [markdown]
# So, what was the point of this exercise? This was a visual demonstration of a high-bias, low-variance model.
#
# - It's **high bias** because it doesn't fit the data particularly well.
# - It's **low variance** because it doesn't change much depending on which observations happen to be available in that universe.

# %% [markdown]
# <a id="lets-try-something-completely-different"></a>
# ### Let's Try Something Completely Different

# %% [markdown]
# What would a **low bias, high variance** model look like? Let's try polynomial regression with an eighth-order polynomial.

# %%
sns.lmplot(x='body', y='brain', data=mammals, ci=None, col='zoologist', order=8);
plt.xlim(-10, 200);
plt.ylim(-10, 250);

# %% [markdown]
# - It's **low bias** because the models match the data effectively.
# - It's **high variance** because the models are widely different, depending on which observations happen to be available in that universe. (For a body weight of 100 kg, the brain weight prediction would be 40 kg in one universe and 0 kg in the other!)

# %%
sns.lmplot(x='body', y='brain', data=mammals, ci=None, hue='zoologist', order=8);
plt.xlim(-10, 200);
plt.ylim(-10, 250);

# %% [markdown]
# <a id="balancing-bias-and-variance"></a>
# ## Balancing Bias and Variance
# Can we find a middle ground?

# %% [markdown]
# Perhaps we can create a model that has **less bias than the linear model** and **less variance than the eighth order polynomial**?
#
# Let's try a second order polynomial instead:

# %%
sns.lmplot(x='body', y='brain', data=mammals, ci=None, col='zoologist', order=2);
plt.xlim(-10, 200);
plt.ylim(-10, 250);

# %%
sns.lmplot(x='body', y='brain', data=mammals, ci=None, hue='zoologist', order=2);
plt.xlim(-10, 200);
plt.ylim(-10, 250);

# %% [markdown]
# This seems better. In both the left and right plots, **it fits the data well, but not too well**.
#
# This is the essence of the **bias-variance trade-off**: You are seeking a model that appropriately balances bias and variance and thus will generalize to new data (known as "out-of-sample" data).

# %% [markdown]
# We want a model that best balances bias and variance. It
# should match our training data well (moderate bias) yet be low variance for out-of-sample data (moderate variance).

# %% [markdown]
# - Training error as a function of
# complexity.
# - Question: Why do we even
# care about variance if we
# know we can generate a
# more accurate model with
# higher complexity?

# %% [markdown]
# ### Can we obtain a zero-bias, zero-variance model?
#
# No! If there is any noise in the data-generating process, then a zero-variance model would not be learning from the data. Additionally, a model only has zero bias if the true relationship between the target and the features is hard-coded into it. If that were the case, you wouldn't be doing machine learning -- it would be similar to trying to predict today's temperature by using today's temperature!

# %% [markdown]
# ---
#
# <a id="train-test-split"></a>
# ## Section 2: Train-test-split

# %% [markdown]
# For the rest of the lab, we will look at three evaluation procedures for predicting model out-of-sample accuracy:
#
# 1. **Train on the entire dataset** should never be done to estimate model accuracy on out-of-sample data! After all, training error can be made arbitrarily small or large. You might train on the entire dataset as the very last step when a model is chosen, hoping to make the final model as accurate as possible. Or, you could use this to estimate the degree of overfitting.
# 2. **Train-test-split** is useful if cross-validation is not practical (e.g. it takes too long to train). It is also useful for computing a quick confusion matrix. You could also use this as a final step after the model is finalized (often called evaluating the model against a **validation set**).
# 3. **Cross-validation** is the gold standard for estimating accuracy and comparing accuracy across models.
# 4. **Three-way split** combines cross-validation and the train-test-split. It takes an initial split to be used as a final validation set, then uses cross-validation on the rest.

# %% [markdown]
# We run into a problem when powerful models can perfectly fit the data on which they are trained. These models are **low bias** and **high variance**. However, we can't observe the variance of a model directly, because we only know how it fits the data we have rather than all potential samples.
#
# **Solution:** Create a procedure that **estimates** how well a model is likely to perform on out-of-sample data and use that to choose between models.
#
#
# **Note:** These procedures can be used with **any machine learning model**.

# %% [markdown]
# **The Holdout Method: Train/Test Split**
# - **Training set**: Used to train the classifier.
# - **Testing set**: Used to estimate the error rate of the trained classifier.
# - **Advantages**: Fast, simple, computationally inexpensive.
# - **Disadvantages** Eliminates data, imperfectly splits.

# %% [markdown]
# <a id="evaluation-procedure--train-and-test-on-the-entire-dataset-do-not-do-this"></a>
# ### Evaluation Procedure #1: Train and Test on the Entire Data Set (Do Not Do This)

# %% [markdown]
# 1. Train the model on the **entire data set**.
# 2. Test the model on the **same data set** and evaluate how well we did by comparing the **predicted** response values with the **true** response values.

# %% [markdown]
# #### Load in the Diabetes data.

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_diabetes

diabetes = load_diabetes()

# %%
print(diabetes.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, T-Cells (a type of white blood cells)
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, thyroid stimulating hormone
#       - s5      ltg, lamotrigine
#       - s6      glu, blood sugar level
#
# Note: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times `n_samples` (i.e. the sum of squares of each column totals 1).
#
# Source URL:
# https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html
#
# For more information see:
# Bradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.
# (https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)

# %% [markdown]
# #### Create X and y variable to stores the feature matrix and response from the diabetes data.

# %%
# Create a DataFrame for both parts of data; don't forget to assign column names.
X = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
y = pd.DataFrame(diabetes.target, columns=['DISPROG'])

# %% [markdown]
# #### Concatenate y and X, then overwrite the diabetes variable.

# %%
diabetes = pd.concat([y, X], axis=1)

# %% [markdown]
# #### Perform basic EDA to make sure the data are in order.

# %%
diabetes.isnull().sum()
# Out:
# DISPROG    0
# age        0
# sex        0
# bmi        0
# bp         0
# s1         0
# s2         0
# s3         0
# s4         0
# s5         0
# s6         0
# dtype: int64

# %%
diabetes.dtypes
# Out:
# DISPROG    float64
# age        float64
# sex        float64
# bmi        float64
# bp         float64
# s1         float64
# s2         float64
# s3         float64
# s4         float64
# s5         float64
# s6         float64
# dtype: object

# %%
diabetes.describe()
# Out:
#           DISPROG           age           sex           bmi            bp  \
# count  442.000000  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   152.133484 -3.634285e-16  1.308343e-16 -8.045349e-16  1.281655e-16
# std     77.093005  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min     25.000000 -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01
# 25%     87.000000 -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02
# 50%    140.500000  5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03
# 75%    211.500000  3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02
# max    346.000000  1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01
#
#                  s1            s2            s3            s4            s5  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -8.835316e-17  1.327024e-16 -4.574646e-16  3.777301e-16 -3.830854e-16
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.267807e-01 -1.156131e-01 -1.023071e-01 -7.639450e-02 -1.260974e-01
# 25%   -3.424784e-02 -3.035840e-02 -3.511716e-02 -3.949338e-02 -3.324879e-02
# 50%   -4.320866e-03 -3.819065e-03 -6.584468e-03 -2.592262e-03 -1.947634e-03
# 75%    2.835801e-02  2.984439e-02  2.931150e-02  3.430886e-02  3.243323e-02
# max    1.539137e-01  1.987880e-01  1.811791e-01  1.852344e-01  1.335990e-01
#
#                  s6
# count  4.420000e+02
# mean  -3.412882e-16
# std    4.761905e-02
# min   -1.377672e-01
# 25%   -3.317903e-02
# 50%   -1.077698e-03
# 75%    2.791705e-02
# max    1.356118e-01

# %% [markdown]
# #### Prepare a feature matrix (X) and response (y)  for scikit-learn.

# %%
# create feature matrix (X)
feature_cols = diabetes.columns.drop(['DISPROG'])
X = diabetes[feature_cols]

# create response vector (y)
y = diabetes.DISPROG

# %% [markdown]
# #### Import linear regression, instantiate, fit, and preview predictions.

# %%
# Import the class.
from sklearn.linear_model import LinearRegression

# Instantiate the model.
lr = LinearRegression()

# Train the model on the entire data set.
lr.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# #### Store the predicted response values.

# %%
y_pred = lr.predict(X)

# %% [markdown]
# To evaluate a model, we also need an **evaluation metric:**
#
# - A numeric calculation used to **quantify** the performance of a model.
# - The appropriate metric depends on the **goals** of your problem.
#
# The most common choices for regression problems are:
#
# - **R-squared**: The percentage of variation explained by the model (a "reward function," as higher is better).
# - **Mean squared error**: The average squared distance between the prediction and the correct answer (a "loss function," as lower is better).
#
# In this case, we'll use mean squared error because it is more interpretable in a predictive context.

# %% [markdown]
# #### Compute mean squared error using a function from `metrics`.

# %%
print('R-Squared: ' + str(lr.score(X,y)))

from sklearn import metrics

print('MSE: ' + str(metrics.mean_squared_error(y, y_pred)))
# Out:
# R-Squared: 0.5177494254132934
# MSE: 2859.6903987680657

# %% [markdown]
# This is known as the **training mean squared error** because we are evaluating the model based on the same data we used to train the model.

# %% [markdown]
# <a id="problems-with-training-and-testing-on-the-same-data"></a>
# ### Problems With Training and Testing on the Same Data
#
# - Our goal is to estimate likely performance of a model on **out-of-sample data**.
# - But, maximizing the training mean squared error rewards **overly complex models** that won't necessarily generalize.
# - Unnecessarily complex models **overfit** the training data.
#     - They will do well when tested using the in-sample data.
#     - They may do poorly with out-of-sample data.
#     - They learn the "noise" in the data rather than the "signal."
#     - From Quora: [What is an intuitive explanation of overfitting?](http://www.quora.com/What-is-an-intuitive-explanation-of-overfitting/answer/Jessica-Su)
#
# **Thus, the training MSE is not a good estimate of the out-of-sample MSE.**

# %% [markdown]
# <a id="evaluation-procedure--traintest-split"></a>
# ### Evaluation procedure #2: Train/Test Split

# %% [markdown]
# 1. Split the data set into two pieces: a **training set** and a **testing set**.
# 2. Train the model on the **training set**.
# 3. Test the model on the **testing set** and evaluate how well we did.
#
# Often a good rule-of-thumb is 70% training/30% test, but this can vary based on the size of your dataset. For example, with a small dataset you would need to use as much training data as possible (in return, your test accuracy will be more variable).
#
# What does this accomplish?
#
# - Models can be trained and tested on **different data** (We treat testing data like out-of-sample data).
# - Response values are known for the testing set and thus **predictions can be evaluated**.
#
# This is known as the **testing mean squared error** because we are evaluating the model on an independent "test set" that was not used during model training.
#
# **The testing MSE is a better estimate of out-of-sample performance than the training MSE.**

# %% [markdown]
# ## Exercise
#
# #### 1) Build a linear regression model for the diabetes dataset using train_test_split. Initially make the split 70/30 and evaluate the model by calculating the MSE

# %%
from sklearn.model_selection import train_test_split

# %%
# A:

# %% [markdown]
# Click here for solution
#
# <span style ='color:white'>
#
# X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.7)
#
# lr_tts=LinearRegression().fit(X_train,y_train)
#
# y_pred=lr_tts.predict(X_test)
#
# print('Test MSE: ' + str(metrics.mean_squared_error(y_pred,y_test)))

# %% [markdown]
# #### Try changing the `train_size` parameter to see what effect this has on your model

# %% [markdown]
# #### 2) Explore the `random_state` Parameter
#
# The `random_state` is a pseudo-random number that allows us to reproduce our results every time we run them. However, it makes it impossible to predict what are exact results will be if we chose a new `random_state`.
#
# `random_state` is very useful for testing that your model was made correctly since it provides you with the same split each time. However, **make sure you remove it if you are testing for model variability!**

# %%
# WITHOUT a random_state parameter:
#  (If you run this code several times, you get different results!)
X_train, X_test, y_train, y_test = train_test_split(X, y)

# Print the first element of each object.
print(X_train.head(1))
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 425 -0.078165 -0.044642 -0.040696 -0.081414 -0.100638 -0.112795  0.022869
#
#            s4        s5        s6
# 425 -0.076395 -0.020289 -0.050783

# %%
# WITH a random_state parameter:
#  (Same split every time! Note you can change the random state to any integer.)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# Print the first element of each object.
print(X_train.head(1))
print(X_test.head(1))
print(y_train.head(1))
print(y_test.head(1))
# Out:
#           age      sex       bmi        bp        s1        s2        s3  \
# 168  0.001751  0.05068  0.059541 -0.002228  0.061725  0.063195 -0.058127
#
#            s4        s5        s6
# 168  0.108111  0.068982  0.127328
#           age       sex       bmi        bp        s1        s2        s3  \
# 246  0.041708 -0.044642 -0.032073 -0.061904  0.079612  0.050982  0.056003
#
#            s4        s5        s6
# 246 -0.009972  0.045066 -0.059067
# 168    268.0
# Name: DISPROG, dtype: float64
# 246    78.0
# Name: DISPROG, dtype: float64

# %% [markdown]
# #### 3) Go back to Step 1 and try adding new variables and transformations. Try using StandardScaler.

# %% [markdown]
# - **Training error**: Decreases as model complexity increases (lower value of k).
# - **Testing error**: Is minimized at the optimum model complexity.

# %%
# A:

# %% [markdown]
# <a id="k-folds-cross-validation"></a>
# ## Section 3: K-Folds Cross-Validation
# ---

# %% [markdown]
# Train/test split provides us with helpful tool, but it's a shame that we are tossing out a large chunk of our data for testing purposes.
#
# **How can we use the maximum amount of our data points while still ensuring model integrity?**
#
# 1. Split our data into a number of different pieces (folds).
# 2. Train using `k-1` folds for training and a different fold for testing.
# 3. Average our model against EACH of those iterations.
# 4. Choose our model and TEST it against the final fold.
# 5. Average all test accuracies to get the estimated out-of-sample accuracy.
#
# Although this may sound complicated, we are just training the model on k separate train-test-splits, then taking the average of the resulting test accuracies!

# %% [markdown]
# ![](./assets/cross_validation_diagram.png)

# %% [markdown]
# <a id="intro-to-cross-validation-with-the-boston-data"></a>
# ### Exercise: Cross-Validation With the diabetes Data

# %% [markdown]
# #### 1) Run the code below for a demonstration of how cross validation works

# %%
from sklearn import model_selection
kf = model_selection.KFold(n_splits=5, shuffle=True)

mse_values = []
scores = []
n = 0

print("~~~~ CROSS VALIDATION each fold ~~~~")
for train_index, test_index in kf.split(X, y):
    lr = LinearRegression().fit(X.iloc[train_index], y.iloc[train_index])
    
    mse_values.append(metrics.mean_squared_error(y.iloc[test_index], lr.predict(X.iloc[test_index])))
    scores.append(lr.score(X, y))
    
    n += 1
    
    print('Model {}'.format(n))
    print('MSE: {}'.format(mse_values[n-1]))
    print('R2: {}\n'.format(scores[n-1]))


print("~~~~ SUMMARY OF CROSS VALIDATION ~~~~")
print('Mean of MSE for all folds: {}'.format(np.mean(mse_values)))
print('Mean of R2 for all folds: {}'.format(np.mean(scores)))
# Out:
# ~~~~ CROSS VALIDATION each fold ~~~~
# Model 1
# MSE: 3906.0997811970283
# R2: 0.513252110315604
#
# Model 2
# MSE: 2666.842376150657
# R2: 0.5138117060165219
#
# Model 3
# MSE: 2911.7646062017334
# R2: 0.5136225818897864
#
# Model 4
# MSE: 3112.4168753817403
# R2: 0.513278110272568
#
# Model 5
# MSE: 2771.9892545624525
# R2: 0.5143471276544702
#
# ~~~~ SUMMARY OF CROSS VALIDATION ~~~~
# Mean of MSE for all folds: 3073.8225786987227
# Mean of R2 for all folds: 0.5136623272297902

# %% [markdown]
# #### 2) Create a cross-validation with five folds and return the score for each model, and the average score

# %%
from sklearn.model_selection import cross_val_score, KFold

# %%
# A:

# %% [markdown]
# Click here for solution
#
# <span style ='color:white'>
#
# lr=LinearRegression()
# print(cross_val_score(lr,X,y))
# print(cross_val_score(lr,X,y).mean())

# %% [markdown]
# #### Extend: Write a loop that cycles through 2 to 10 folds, calculating the average score for each. Which number of folds produces the best average score?

# %%
# A:

# %% [markdown]
# Click here for solution
#
# <span style ='color:white'>
#
# for n in range(2,11):
#     kf=KFold(n_splits=n,shuffle=True)
#     print(str(n) + ' folds average score: ' + str(cross_val_score(lr,X,y,cv=kf).mean()))

# %% [markdown]
# While the cross-validated approach here generated more overall error, which of the two approaches would predict new data more accurately — the single model or the cross-validated, averaged one? Why?

# %%
# A:

# %% [markdown]
# <a id="three-way-data-split"></a>
# ## Section 4: Three-Way Data Split
# ---
#
# The most common workflow is actually a combination of train/test split and cross-validation. We take a train/test split on our data right away and try not spend a lot of time using the testing data set. Instead, we take our training data and tune our models using cross-validation. When we think we are done, we do one last test on the testing data to make sure we haven't accidently overfit to our training data.
#
# **If you tune hyperparameters via cross-validation, you should never use cross-validation on the same dataset to estimate OOS accuracy!** Using cross-validation in this way, the entire dataset was used to tune hyperparameters. So, this invalidates our condition above -- where we assumed the test set is a pretend "out-of-sample" dataset that was not used to train our model! So, we would expect the accuracy on this test set to be artificially inflated as compared to actual "out-of-sample" data.
#
# Even with good evaluation procedures, it is incredible easy to overfit our models by including features that will not be available during production or leak information about our testing data in other ways.

# %% [markdown]
# ![](./assets/Train-Test-Split-CV.png)

# %% [markdown]
# - If model selection and true error estimates are to be computed simultaneously, three disjointed data sets are best.
#     - **Training set**: A set of examples used for learning – what parameters of the classifier?
#     - **Validation set**: A set of examples used to tune the parameters of the classifier.
#     - **Testing set**: A set of examples used ONLY to assess the performance of the fully trained classifier.
# - Validation and testing must be separate data sets. Once you have the final model set, you cannot do any additional tuning after testing.

# %% [markdown]
# ### Exploring RidgeCV
#
# Run the code below to see how we can do a three-way split

# %%
from sklearn.linear_model import RidgeCV

# %%
# Create our train/test split as usual
X_train, X_test, y_train, y_test=train_test_split(X,y,train_size=0.7)

# %%
# Build our estimator and define what levels of alpha we want it to test when tuning, with 5 cross-folds
ridge=RidgeCV(alphas=[0.1,1.0,10.0],cv=5)

# %%
# Fit our training data
ridge.fit(X_train,y_train)
# Out:
# RidgeCV(alphas=array([ 0.1,  1. , 10. ]), cv=5)

# %%
# Test our tuned model with our held back testing set
ridge.score(X_test,y_test)
# Out:
# 0.5295296855242049

# %%
# What alpha did the estimator decide on?
ridge.alpha_
# Out:
# 0.1

# %% [markdown]
# ### Exploring LassoCV
#
# Run the code below to see how we can do a three-way split with Lasso

# %%
from sklearn.linear_model import LassoCV

# %%
# Create our train/test split as usual
X_train, X_test, y_train, y_test=train_test_split(X,y,train_size=0.7)

# %%
# Build estimator with various alphas and fit training data for cross validation
lasso=LassoCV(alphas=[0.1,0.5,1.0],cv=5).fit(X_train,y_train)

# %%
# Test estimator with held back data
lasso.score(X_test,y_test)
# Out:
# 0.48279821801957135

# %%
# Which alpha was best?
lasso.alpha_
# Out:
# 0.1

# %% [markdown]
# ### Extension: Exploring GridSearchCV
#
# Gridsearch is a power cross validation tool that allows us to tune multiple hyper-parameters. Note, that this can sometimes take a long time to run, depending on the complexity of the model. This can be used for any estimator.
#
# Run the code below to see how it works

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# To use gridsearch we need to define what estimator we are using and create a dictionary of the hyper-parameters we would like to tune, including what values they are being tuned to. The following example shows how we can fine tune the LassoCV estimator if we wanted to try different values for `max_iter`.

# %%
# Define the estimator we would like to use
estimator=LassoCV()
# Create dictionary of hyper-parameters we would like to tune
params={'max_iter':[10,100,1000]}

# %%
# Build the GridSearchCV cross validation with estimator and parameters to be tuned, define number of crossfolds
grid=GridSearchCV(estimator,params,cv=5)

# %%
# Fit our training data
grid.fit(X_train,y_train)
# Out:
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 252.60182591341436, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 311.28268997662235, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 314.73817459261045, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 303.0190155644668, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 287.80748361349106, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 272.37887311470695, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 257.6105273409048, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 243.7048797159223, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 230.67670620407443, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 218.4903325792402, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3069.1851351551013, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8877.686843553907, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15187.663646658184, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21216.44544004876, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26687.082958075567, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31531.378812974144, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35767.80925194116, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39448.45652071369, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20938.515109112777, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13138.447151380591, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9111.362192855275, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7020.156864894787, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13915.76430768799, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24056.86828866217, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33397.26222233678, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41563.58334882121, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48571.72561322164, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54547.68206426047, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 59636.862612096535, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 63974.968772682885, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 67679.98835354665, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 70851.6030200767, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 73573.04357567261, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 75913.5377507545, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77930.673322324, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 79672.4597529553, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 81179.0504216642, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 82484.15270706621, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 83616.1722804443, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 84599.13897875039, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 85453.45624995005, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 86196.50921486237, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 86843.15974010725, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 87406.15118910477, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 87896.44081980106, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 88323.47403392708, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 88695.4117092173, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 89019.31951149722, tolerance: 115.80359492385789
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 213.58028768084478, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 244.70741444907617, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 244.48940777312964, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 235.82311044505332, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 225.34268295904621, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 214.8810060248943, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 204.9164916666923, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1781.1127345616696, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7439.172028533299, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14191.694422146655, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20883.14830473531, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27078.76136046066, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32641.80588108767, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37561.330973074306, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35750.87065272132, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17266.703005151125, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11483.951159113203, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8455.208233329584, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11039.430928221554, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22034.190849809267, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32472.657418594987, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41749.23115807667, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49794.04803891311, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 56707.446324226155, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62633.276733897044, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 67714.56941875856, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 72079.2474198105, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 75837.0225822815, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 79080.32386060944, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 81886.48037664982, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 84320.08860677021, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 86435.17764186766, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 88277.06223319873, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 89883.88107778702, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 91287.85569237283, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 92516.31443202076, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93592.5242391947, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94536.36700665727, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 95364.89107947043, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 96092.76258553079, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 96732.63633238265, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 97295.46196700513, tolerance: 118.24772081218273
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152.88187698507681, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 303.39199521392584, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 335.46408543991856, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 331.5622732975753, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 318.0114406711655, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 302.5019724916201, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 287.19370335841086, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4875.2390369684435, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12208.295434425701, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20135.768758948136, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27834.57248166058, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34975.23137604224, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41450.15515722294, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47252.79396049364, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22238.879111774615, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13156.900063347071, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8709.529215713497, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13205.396147668594, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25652.969559903722, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37780.13268663199, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48747.90401080804, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 58405.1001264535, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 66824.27060039603, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 74142.52030287503, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 80505.42911413184, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 86047.59419972729, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90886.98330904054, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 95124.57578426937, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98845.90928942792, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 102123.15805971046, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 105017.19497514528, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 107579.43886003736, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 109853.43566423992, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 111876.18187356193, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 113679.21991579112, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 115289.54027064343, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 116730.32321760192, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 118021.54902495336, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119180.50079197131, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 120222.17987626448, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 121159.65013707467, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 122004.32413359426, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 122766.2018926776, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 123454.0708176111, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 124075.67366469803, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 124637.85019868764, tolerance: 129.78956767676766
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2389.7540925458306, tolerance: 121.78401464646464
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7711.729868697759, tolerance: 121.78401464646464
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13639.10488906398, tolerance: 121.78401464646464
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19340.235345776076, tolerance: 121.78401464646464
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24519.48431294848, tolerance: 121.78401464646464
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29100.730994593934, tolerance: 121.78401464646464
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33099.73846718477, tolerance: 121.78401464646464
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 36801.67260384449, tolerance: 121.78401464646464
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40638.67038878426, tolerance: 121.78401464646464
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44002.47909267526, tolerance: 121.78401464646464
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 46950.47037408588, tolerance: 121.78401464646464
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30213.738254721742, tolerance: 121.78401464646464
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18650.69031158666, tolerance: 121.78401464646464
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7447.216744345264, tolerance: 121.78401464646464
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15828.649320817145, tolerance: 121.78401464646464
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24387.342863686907, tolerance: 121.78401464646464
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32081.359413342085, tolerance: 121.78401464646464
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40266.09217054624, tolerance: 121.78401464646464
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47369.76049269247, tolerance: 121.78401464646464
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 53512.166454266, tolerance: 121.78401464646464
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 58805.08421757922, tolerance: 121.78401464646464
#   model = cd_fast.enet_coordinate_descent_gram(
# ...
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 53569.4536189381, tolerance: 154.3089117408907
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 60342.97264612035, tolerance: 154.3089117408907
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 66585.87497594784, tolerance: 154.3089117408907
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 72327.39656469587, tolerance: 154.3089117408907
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77603.10270277056, tolerance: 154.3089117408907
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 82450.31920806062, tolerance: 154.3089117408907
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 86905.67702536326, tolerance: 154.3089117408907
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 91003.85446022957, tolerance: 154.3089117408907
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94777.00025489315, tolerance: 154.3089117408907
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98254.54124202882, tolerance: 154.3089117408907
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 101463.20284418168, tolerance: 154.3089117408907
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 104427.14227387874, tolerance: 154.3089117408907
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 107168.13604560238, tolerance: 154.3089117408907
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 109705.64890456281, tolerance: 154.3089117408907
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 112054.35959852132, tolerance: 154.3089117408907
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 114230.92885324522, tolerance: 154.3089117408907
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 116252.2574408222, tolerance: 154.3089117408907
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 118131.36511432094, tolerance: 154.3089117408907
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119879.8698647747, tolerance: 154.3089117408907
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 121508.26257206948, tolerance: 154.3089117408907
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 243.9563152140472, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4549.11768183473, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10849.028854940669, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17329.81317137601, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23335.6074339475, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28661.89461103466, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33285.41845056042, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37253.81950648234, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40638.75409605843, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43515.79774559883, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45956.118952301214, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48023.44031879277, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49773.3736241397, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 53343.280310421425, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 56358.090914038126, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 58993.93076015258, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 61291.95192408265, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 63294.85781393753, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 65041.063122962136, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 66564.1281206375, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 67893.15756817441, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 69053.34796458902, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 70066.51168426668, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 70951.54342549341, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 71724.82570244756, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 72400.57797173056, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 72991.15591399785, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 73507.30752432364, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 73958.39217179368, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 74352.56809455046, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 74696.9530659091, tolerance: 152.8381483870968
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Joseph\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 394356.0910658871, tolerance: 188.85142588996763
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=LassoCV(),
#              param_grid={'max_iter': [10, 100, 1000]})

# %%
# Which model was best
grid.best_estimator_
# Out:
# LassoCV(max_iter=10)

# %%
# What is the score of this best estimator on unseen data?
grid.best_estimator_.score(X_test,y_test)
# Out:
# 0.47996505703547465

# %% [markdown]
# <a id="additional-resources"></a>
# <a id="additional-resources"></a>
# ### Additional Resources
# - [Bias Variance](http://scott.fortmann-roe.com/docs/BiasVariance.html)
# - University of Washington [slides](https://courses.cs.washington.edu/courses/cse546/12wi/slides/)

# %% [markdown]
# <a id="summary"></a>
# ### Summary
#
# In this lab, we compared four methods of estimating model accuracy on out-of-sample data. Throughout your regular data science work, you will likely use all four at some point:
#
# 1. **Train on the entire dataset**
# 2. **Train-test-split**
# 3. **Cross-validation**
# 4. **Three-way split**
